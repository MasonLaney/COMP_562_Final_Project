# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
dataset_excel = pd.read_excel('augmented_macro_features.xlsx',['features'])
dataset = dataset_excel['features']

# %%
dataset.columns
# Out:
# Index(['SPY % Change (Rolling last 21 observations) 1 month ahead',
#        '2yr US Gov Treasury Yield % Change (Rolling last 21 observations)',
#        '10yr US Gov Treasury Yield % Change (Rolling last 21 observations)',
#        '10yr TIPS (Inflation Indexed US Treasury) % Change (Rolling last 21 observations)',
#        'Inflation (10yr - 10 yr TIPS) % Change (Rolling last 21 observations)',
#        '10yr-2yr US Treasury Yield Curve % Change (Rolling last 21 observations)',
#        'Junk/High Yield Corporate Debt % Change (Rolling last 21 observations)',
#        'Junk/High Yield Corporate Debt - 10yr US Treasury Spread % Change (Rollins last 21 observations)',
#        'VIX (Volatility Index "fear" guage) % Change (Rolling last 21 observations)',
#        'ISM Manufacturing Index % Change (Monthly) Forward Fill',
#        'ISM Manufacturing Growth/Contraction (Monthly)',
#        'M2 Money Supply % Change (Monthly) Forward Fill',
# ...

# %%
dataset['SPY % Change (Rolling last 21 observations) 1 month ahead'].plot.hist(bins=30)
plt.show()
dataset['SPY % Change (Rolling last 21 observations) 1 month ahead'].describe()
# Out:
# count    4788.000000
# mean        0.846381
# std         4.521231
# min       -37.280959
# 25%        -1.076805
# 50%         1.440165
# 75%         3.306065
# max        23.750337
# Name: SPY % Change (Rolling last 21 observations) 1 month ahead, dtype: float64

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','2yr US Gov Treasury Yield % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='2yr US Gov Treasury Yield % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','10yr US Gov Treasury Yield % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='10yr US Gov Treasury Yield % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','10yr TIPS (Inflation Indexed US Treasury) % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='10yr TIPS (Inflation Indexed US Treasury) % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','Inflation (10yr - 10 yr TIPS) % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='Inflation (10yr - 10 yr TIPS) % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','10yr-2yr US Treasury Yield Curve % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='10yr-2yr US Treasury Yield Curve % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','Junk/High Yield Corporate Debt % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='Junk/High Yield Corporate Debt % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','Junk/High Yield Corporate Debt - 10yr US Treasury Spread % Change (Rollins last 21 observations)']].plot.scatter(x=1,y=0)
plt.xlabel('Junk/HY - 10yr US Treasury Spread % Change (Rollins last 21 observations)')
# Out:
# Text(0.5, 0, 'Junk/HY - 10yr US Treasury Spread % Change (Rollins last 21 observations)')

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','VIX (Volatility Index "fear" guage) % Change (Rolling last 21 observations)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='VIX (Volatility Index "fear" guage) % Change (Rolling last 21 observations)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','ISM Manufacturing Index % Change (Monthly) Forward Fill']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='ISM Manufacturing Index % Change (Monthly) Forward Fill', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','ISM Manufacturing Growth/Contraction (Monthly)']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='ISM Manufacturing Growth/Contraction (Monthly)', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','M2 Money Supply % Change (Monthly) Forward Fill']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='M2 Money Supply % Change (Monthly) Forward Fill', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','University of Michigan Consumer Sentiment Index (Composite) (Monthly) % Change Forward Fill']].plot.scatter(x=1,y=0)
plt.xlabel('UMCSI (Composite) (Monthly) % Change Forward Fill')
# Out:
# Text(0.5, 0, 'UMCSI (Composite) (Monthly) % Change Forward Fill')

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','UMCSI (Future Expectations) (Monthly) % Change Forward Fill']].plot.scatter(x=1,y=0)
# Out:
# Text(0.5, 0, 'UMCSI (Composite) (Monthly) % Change Forward Fill')

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','UMCSI (Current Conditions) (Monthly) % Change Forward Fill']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='UMCSI (Current Conditions) (Monthly) % Change Forward Fill', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>

# %%
dataset[['SPY % Change (Rolling last 21 observations) 1 month ahead','New Residential Construction Permits (Monthly) % Change Forward Fill']].plot.scatter(x=1,y=0)
# Out:
# <AxesSubplot:xlabel='New Residential Construction Permits (Monthly) % Change Forward Fill', ylabel='SPY % Change (Rolling last 21 observations) 1 month ahead'>
